# %%
dirpath = "/nfs/turbo/umms-indikar/shared/projects/poreC/data/raw_sequencing_files/"

for j in range(1, 4):
    for i in range(1, 96):
        print(f"o{j}b{str(i).zfill(2)},{dirpath}scPC96o{j}/merged_pod5/barcode{str(i).zfill(2)}.pod5")
# Out:
# o1b01,/nfs/turbo/umms-indikar/shared/projects/poreC/data/raw_sequencing_files/scPC96o1/merged_pod5/barcode01.pod5
# o1b02,/nfs/turbo/umms-indikar/shared/projects/poreC/data/raw_sequencing_files/scPC96o1/merged_pod5/barcode02.pod5
# o1b03,/nfs/turbo/umms-indikar/shared/projects/poreC/data/raw_sequencing_files/scPC96o1/merged_pod5/barcode03.pod5
# o1b04,/nfs/turbo/umms-indikar/shared/projects/poreC/data/raw_sequencing_files/scPC96o1/merged_pod5/barcode04.pod5
# o1b05,/nfs/turbo/umms-indikar/shared/projects/poreC/data/raw_sequencing_files/scPC96o1/merged_pod5/barcode05.pod5
# o1b06,/nfs/turbo/umms-indikar/shared/projects/poreC/data/raw_sequencing_files/scPC96o1/merged_pod5/barcode06.pod5
# o1b07,/nfs/turbo/umms-indikar/shared/projects/poreC/data/raw_sequencing_files/scPC96o1/merged_pod5/barcode07.pod5
# o1b08,/nfs/turbo/umms-indikar/shared/projects/poreC/data/raw_sequencing_files/scPC96o1/merged_pod5/barcode08.pod5
# ...
